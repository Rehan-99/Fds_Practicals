# %% [markdown]
# # Seaborn
# Seaborn is pyhton data visualization library based on matplotlib It provides high level interface for drawing attractive and infromative statistical graphics

# %%
cars= pd.read_csv('Toyota.csv',index_col=0,na_values=["??","????"])
cars.size
# Out:
# 14360

# %%
cars.head()
# Out:
#    Price   Age       KM FuelType    HP  MetColor  Automatic    CC  Doors  \
# 0  13500  23.0  46986.0   Diesel  90.0       1.0          0  2000  three
# 1  13750  23.0  72937.0   Diesel  90.0       1.0          0  2000      3
# 2  13950  24.0  41711.0   Diesel  90.0       NaN          0  2000      3
# 3  14950  26.0  48000.0   Diesel  90.0       0.0          0  2000      3
# 4  13750  30.0  38500.0   Diesel  90.0       0.0          0  2000      3
#
#    Weight
# 0    1165
# 1    1165
# 2    1165
# 3    1165
# 4    1170

# %%
cars.dropna(axis=0,inplace =True)
cars.size
# Out:
# 10960

# %%
cars.head()
# Out:
#    Price   Age       KM FuelType    HP  MetColor  Automatic    CC  Doors  \
# 0  13500  23.0  46986.0   Diesel  90.0       1.0          0  2000  three
# 1  13750  23.0  72937.0   Diesel  90.0       1.0          0  2000      3
# 3  14950  26.0  48000.0   Diesel  90.0       0.0          0  2000      3
# 4  13750  30.0  38500.0   Diesel  90.0       0.0          0  2000      3
# 5  12950  32.0  61000.0   Diesel  90.0       0.0          0  2000      3
#
#    Weight
# 0    1165
# 1    1165
# 3    1165
# 4    1170
# 5    1170

# %%
sns.set(style='darkgrid')
sns.regplot(x=cars['Age'],y=cars['Price'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Price'>

# %%
sns.regplot(x=cars['Age'],y=cars['Price'],marker='*',fit_reg =False)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Price'>

# %%
sns.lmplot(x='Age',y='Price',data=cars ,fit_reg=False,hue='FuelType',legend=True,palette='Set2')

# %%
sns.displot(cars['Age'],kde="True")

# %%
sns.displot(cars['Age'],bins=5)

# %%
sns.countplot(x='FuelType', data=cars)
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='count'>

# %%
sns.countplot(x='FuelType',data=cars,hue='Automatic')
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='count'>

# %%
pd.crosstab(index=cars['Automatic'],columns=cars['FuelType'],dropna=True)
# Out:
# FuelType   CNG  Diesel  Petrol
# Automatic
# 0           12     116     910
# 1            0       0      58

# %% [markdown]
# # Box and whiskers plot
# Box and Whiskers plot for numerical vs categorical variable
#
# A Box plot is also known as whisker plot created to display the summary of the set of data
# values having properties like minimum, first quartile, median, third quartile and maximum.
# In the box plot, a box is created from the first quartile to the third quartile, a vertical
# line is also there which goes through the box at the median. here x-axis denotes the data
# to be plotted while the y-axis shows the frequency distribution.

# %%
sns.boxplot(x=cars['FuelType'],y=cars['Price'])
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='Price'>

# %%
sns.boxplot(x= cars['FuelType'],y=cars['Price'],hue='Automatic',data=cars)
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='Price'>

# %%
f,(ax_box,ax_hist)=plt.subplots(2,gridspec_kw={'height_ratios':(.15,.85)})
sns.boxplot(cars['Price'],ax=ax_box)
sns.distplot(cars['Price'],ax=ax_hist,kde=False)
# Out:
# E:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price'>

# %% [markdown]
# # Pairwise Plot

# %%
sns.pairplot(cars ,kind= 'scatter',hue='FuelType',diag_kws={'bw_method':0.1})

# %%
data = np.random.randint(1,100,size = (10,10))
print("The data to be plotted \n")
data
# Out:
# The data to be plotted
# array([[43, 50, 25, 59, 65, 59, 47, 70, 81, 65],
#        [30, 49, 73, 82, 24, 10, 40, 18, 76, 72],
#        [46, 97, 87, 34, 51, 82, 82, 99, 42, 40],
#        [43, 44, 22, 22, 49, 47, 41, 36, 99, 91],
#        [63, 29, 15, 68,  3, 79, 22, 54, 77, 14],
#        [57, 53, 84, 49, 87,  6, 41, 97, 83, 47],
#        [56, 20, 84, 54, 92,  7, 97, 53, 51, 27],
#        [46, 79, 49, 27, 81, 39, 90, 67, 95, 56],
#        [19, 28, 92,  5, 21,  5, 62, 41,  9, 62],
#        [49, 98, 69, 31, 78, 45, 26, 51, 32, 17]])

# %%
hm =sns.heatmap(data=data)
plt.show()

# %%
hm =sns.heatmap(data=data,
               vmin='30',vmax = '70')

# %%
cmap='tab10'
center=0
annot=True
hm=sns.heatmap(data=data,cmap=cmap,annot=annot)
